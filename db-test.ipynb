# %%
# %run 02Development_Zone/db_connect.py

# %%
# %%dev
# insert into staff_bak0921
# select * from staff;
# commit;
# Out:
# Statement executed successfully.
# Statement executed successfully.

# %%
# %%dev
# select * from staff_bak0921
# Out:
#     staff_id  location_id  job_id first_name last_name home_phone  \
# 0         10           10      10      Harry    Potter   333-9999
# 1         11           10      11      Sandy     Beach   454-8587
# 2         12           11      12      Jason    Bourne   457-8547
# 3         10           10      10      Harry    Potter   333-9999
# 4         11           10      11      Sandy     Beach   454-8587
# 5         12           11      12      Jason    Bourne   457-8547
# 6         10           10      10      Harry    Potter   333-9999
# 7         11           10      11      Sandy     Beach   454-8587
# 8         12           11      12      Jason    Bourne   457-8547
# 9         10           10      10      Harry    Potter   333-9999
# 10        11           10      11      Sandy     Beach   454-8587
# 11        12           11      12      Jason    Bourne   457-8547
#
#    mobile_phone            hire_date                      address  \
# ...

# %%
# %%dev
# update  staff_bak0921
# set mobile_phone = '207890'
# where staff_id = 10;
#
# select * from staff_bak0921
# Out:
# Oracle error: ORA-00933: SQL command not properly ended
# Help: https://docs.oracle.com/error-help/db/ora-00933/

# %%
# %%uat
# select * from staff
# Out:
#    staff_id  location_id  job_id home_phone mobile_phone            hire_date  \
# 0         1           10      10   010-2001  13900000001  2025-06-19T00:00:00
#
#   address                  dob emergency_number  wage_rate wage_interval  \
# 0  北京市朝阳区  1999-12-31T00:00:00             None    12000.0          hour
#
#   payment_schedule gender is_married is_active is_permanent full_name
# 0            month      M          T         T            T        **

# %%
ddl = get_ddl_dev("PACKAGE", "PKG_JTA", schema="DEV")
print(ddl)
# Out:
# CREATE OR REPLACE EDITIONABLE PACKAGE "DEV"."PKG_JTA"
# IS
#     -- some constants
#     nat_insurance_rate CONSTANT NUMBER := 0.132;
#     hlt_surcharge_rate CONSTANT NUMBER := 0.005;
#
#     -- public procedures and functions
#     PROCEDURE sp_process_payroll (
#         p_date IN DATE
#     );
#
#     PROCEDURE sp_update_inventory (
#         p_product_id IN cost_sales_tracker.product_id%TYPE,
#         p_quantity IN NUMBER,
#         p_new_cost IN cost_sales_tracker.cost_per_unit%TYPE
#     );
#
#     PROCEDURE sp_restock_urgent (
#         p_staff_id IN staff.staff_id%TYPE
#     );
#
#     FUNCTION fn_get_last_cashier_payout (
#         p_staff_id staff.staff_id%TYPE
#     ) RETURN cashier_drawer_assignments.cash_amount_end%TYPE;
#
#     FUNCTION fn_get_money_inflow (
#         p_location_id locations.location_id%TYPE,
#         p_start_date DATE,
#         p_end_date DATE,
#         p_type VARCHAR2 := 'cash'
#     ) RETURN cashier_drawer_assignments.cash_amount_start%TYPE;
#
# ...

# %%
# %%sql
